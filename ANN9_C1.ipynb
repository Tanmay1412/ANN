# %%
#!pip install tensorflow
try:
    import tensorflow as tf
except ImportError:
    # !pip install tensorflow
    import tensorflow as tf

import numpy as np
import matplotlib.pyplot as plt

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# %%
x_train = x_train.reshape(-1, 784) / 255.0
x_test = x_test.reshape(-1, 784) / 255.0

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(10, activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=10, validation_split=0.2)
# Out:
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8669 - loss: 0.5073 - val_accuracy: 0.9097 - val_loss: 0.3194
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9113 - loss: 0.3167 - val_accuracy: 0.9194 - val_loss: 0.2880
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9176 - loss: 0.2930 - val_accuracy: 0.9237 - val_loss: 0.2758
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9210 - loss: 0.2812 - val_accuracy: 0.9251 - val_loss: 0.2695
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9227 - loss: 0.2737 - val_accuracy: 0.9265 - val_loss: 0.2692
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9251 - loss: 0.2683 - val_accuracy: 0.9274 - val_loss: 0.2644
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9256 - loss: 0.2638 - val_accuracy: 0.9285 - val_loss: 0.2634
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9278 - loss: 0.2601 - val_accuracy: 0.9277 - val_loss: 0.2642
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9276 - loss: 0.2579 - val_accuracy: 0.9279 - val_loss: 0.2637
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9294 - loss: 0.2546 - val_accuracy: 0.9270 - val_loss: 0.2645

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print("Test Accuracy:", test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9248 - loss: 0.2705
# Test Accuracy: 0.9247999787330627

# %%
plt.plot(history.history['loss'])
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Loss vs Epoch")
plt.grid()
plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Accuracy vs Epoch")
plt.grid()
plt.show()
